# %%
import pandas as pd
pd.options.display.max_columns=200
import matplotlib.pyplot as plt
import numpy as np
from sklearn.preprocessing import StandardScaler
import warnings 
warnings.filterwarnings('ignore')
from sklearn.dummy import DummyRegressor
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import mean_squared_error, mean_squared_log_error
from sklearn.linear_model import Ridge, LinearRegression, Lasso
from sklearn.compose import TransformedTargetRegressor
from sklearn.svm import SVR

# %%
data = pd.read_csv('data.csv')

# %%
data.set_index('OSEBuildingID', inplace = True)

# %%
data
# Out:
#                NumberofBuildings  NumberofFloors  PropertyGFATotal  \
# OSEBuildingID
# 1                            1.0              12             88434
# 2                            1.0              11            103566
# 3                            1.0              41            956110
# 5                            1.0              10             61320
# 8                            1.0              18            175580
# ...                          ...             ...               ...
# 50222                        1.0               1             12294
# 50223                        1.0               1             16000
# 50224                        1.0               1             13157
# 50225                        1.0               1             14101
# 50226                        1.0               1             18258
#
#                LargestPropertyUseTypeGFA  ENERGYSTARScore  SiteEUI(kBtu/sf)  \
# OSEBuildingID
# 1                                88434.0             60.0         81.699997
# 2                                83880.0             61.0         94.800003
# 3                               756493.0             43.0         96.000000
# 5                                61320.0             56.0        110.800003
# 8                               123445.0             75.0        114.800003
# ...                                  ...              ...               ...
# 50222                            12294.0             46.0         69.099998
# 50223                            16000.0              0.0         59.400002
# 50224                             7583.0              0.0        438.200012
# 50225                             6601.0              0.0         51.000000
# 50226                             8271.0              0.0         63.099998
#
#                SiteEUIWN(kBtu/sf)  SourceEUI(kBtu/sf)  SourceEUIWN(kBtu/sf)  \
# OSEBuildingID
# 1                       84.300003          182.500000            189.000000
# 2                       97.900002          176.100006            179.399994
# 3                       97.699997          241.899994            244.100006
# 5                      113.300003          216.199997            224.000000
# 8                      118.699997          211.399994            215.600006
# ...                           ...                 ...                   ...
# 50222                   76.699997          161.699997            176.100006
# 50223                   65.900002          114.199997            118.900002
# 50224                  460.100006          744.799988            767.799988
# 50225                   55.500000          105.300003            110.800003
# 50226                   70.900002          115.800003            123.900002
#
#                EnergyStarNaN  SiteEnergyUse(kBtu)  SiteEnergyUseWN(kBtu)  \
# OSEBuildingID
# 1                          0         7.226362e+06           7.456910e+06
# 2                          0         8.387933e+06           8.664479e+06
# 3                          0         7.258702e+07           7.393711e+07
# 5                          0         6.794584e+06           6.946800e+06
# 8                          0         1.417261e+07           1.465650e+07
# ...                      ...                  ...                    ...
# 50222                      0         8.497457e+05           9.430032e+05
# 50223                      1         9.502762e+05           1.053706e+06
# 50224                      1         5.765898e+06           6.053764e+06
# 50225                      1         7.194712e+05           7.828413e+05
# 50226                      1         1.152896e+06           1.293722e+06
#
#                TotalGHGEmissions  GHGEmissionsIntensity  Age  \
# OSEBuildingID
# 1                         249.98                   2.83   89
# 2                         295.86                   2.86   20
# 3                        2089.28                   2.19   47
# 5                         286.43                   4.67   90
# 8                         505.01                   2.88   36
# ...                          ...                    ...  ...
# 50222                      20.94                   1.70   26
# 50223                      32.17                   2.01   12
# 50224                     223.54                  16.99   42
# 50225                      22.11                   1.57   27
# 50226                      41.27                   2.26   78
#
#                PropertyGFAParking(%)  PropertyGFABuilding(s)(%)  SteamUse(%)  \
# OSEBuildingID
# 1                           0.000000                 100.000000    27.730162
# 2                          14.545314                  85.454686     0.000000
# 3                          20.574829                  79.425171    29.711308
# 5                           0.000000                 100.000000    32.591344
# 8                          35.311539                  64.688461     0.000000
# ...                              ...                        ...          ...
# 50222                       0.000000                 100.000000     0.000000
# 50223                       0.000000                 100.000000     0.000000
# 50224                       0.000000                 100.000000     0.000000
# 50225                       0.000000                 100.000000     0.000000
# 50226                       0.000000                 100.000000     0.000000
#
#                Electricity(%)  NaturalGas(%)  \
# OSEBuildingID
# 1                   54.605993      17.663838
# 2                   38.660907      61.339093
# 3                   68.230741       2.057944
# 5                   40.751928      26.656717
# 8                   37.880168      62.119825
# ...                       ...            ...
# 50222               61.697384      38.302639
# 50223               41.729558      58.270426
# 50224               31.082041      68.917956
# 50225               48.489805      51.510194
# 50226               37.518922      62.481077
#
#                PrimaryPropertyType_Distribution Center  \
# OSEBuildingID
# 1                                                    0
# 2                                                    0
# 3                                                    0
# 5                                                    0
# 8                                                    0
# ...                                                ...
# 50222                                                0
# 50223                                                0
# 50224                                                0
# 50225                                                0
# 50226                                                0
#
#                PrimaryPropertyType_Hotel  PrimaryPropertyType_K-12 School  \
# OSEBuildingID
# 1                                      1                                0
# 2                                      1                                0
# 3                                      1                                0
# 5                                      1                                0
# 8                                      1                                0
# ...                                  ...                              ...
# 50222                                  0                                0
# 50223                                  0                                0
# 50224                                  0                                0
# 50225                                  0                                0
# 50226                                  0                                0
#
#                PrimaryPropertyType_Large Office  \
# OSEBuildingID
# 1                                             0
# 2                                             0
# 3                                             0
# 5                                             0
# 8                                             0
# ...                                         ...
# 50222                                         0
# 50223                                         0
# 50224                                         0
# 50225                                         0
# 50226                                         0
#
#                PrimaryPropertyType_Medical Office  \
# OSEBuildingID
# 1                                               0
# 2                                               0
# 3                                               0
# 5                                               0
# 8                                               0
# ...                                           ...
# 50222                                           0
# 50223                                           0
# 50224                                           0
# 50225                                           0
# 50226                                           0
#
#                PrimaryPropertyType_Mixed Use Property  \
# OSEBuildingID
# 1                                                   0
# 2                                                   0
# 3                                                   0
# 5                                                   0
# 8                                                   0
# ...                                               ...
# 50222                                               0
# 50223                                               0
# 50224                                               0
# 50225                                               1
# 50226                                               1
#
#                PrimaryPropertyType_Other  PrimaryPropertyType_Retail Store  \
# OSEBuildingID
# 1                                      0                                 0
# 2                                      0                                 0
# 3                                      0                                 0
# 5                                      0                                 0
# 8                                      0                                 0
# ...                                  ...                               ...
# 50222                                  1                                 0
# 50223                                  1                                 0
# 50224                                  1                                 0
# 50225                                  0                                 0
# 50226                                  0                                 0
#
#                PrimaryPropertyType_Self-Storage Facility  \
# OSEBuildingID
# 1                                                      0
# 2                                                      0
# 3                                                      0
# 5                                                      0
# 8                                                      0
# ...                                                  ...
# 50222                                                  0
# 50223                                                  0
# 50224                                                  0
# 50225                                                  0
# 50226                                                  0
#
#                PrimaryPropertyType_Small- and Mid-Sized Office  \
# OSEBuildingID
# 1                                                            0
# 2                                                            0
# 3                                                            0
# 5                                                            0
# 8                                                            0
# ...                                                        ...
# 50222                                                        0
# 50223                                                        0
# 50224                                                        0
# 50225                                                        0
# 50226                                                        0
#
#                PrimaryPropertyType_Supermarket / Grocery Store  \
# OSEBuildingID
# 1                                                            0
# 2                                                            0
# 3                                                            0
# 5                                                            0
# 8                                                            0
# ...                                                        ...
# 50222                                                        0
# 50223                                                        0
# 50224                                                        0
# 50225                                                        0
# 50226                                                        0
#
#                PrimaryPropertyType_University  PrimaryPropertyType_Warehouse  \
# OSEBuildingID
# 1                                           0                              0
# 2                                           0                              0
# 3                                           0                              0
# 5                                           0                              0
# 8                                           0                              0
# ...                                       ...                            ...
# 50222                                       0                              0
# 50223                                       0                              0
# 50224                                       0                              0
# 50225                                       0                              0
# 50226                                       0                              0
#
#                PrimaryPropertyType_Worship Facility  CouncilDistrictCode_1  \
# OSEBuildingID
# 1                                                 0                      0
# 2                                                 0                      0
# 3                                                 0                      0
# 5                                                 0                      0
# 8                                                 0                      0
# ...                                             ...                    ...
# 50222                                             0                      0
# 50223                                             0                      0
# 50224                                             0                      0
# 50225                                             0                      1
# 50226                                             0                      0
#
#                CouncilDistrictCode_2  CouncilDistrictCode_3  \
# OSEBuildingID
# 1                                  0                      0
# 2                                  0                      0
# 3                                  0                      0
# 5                                  0                      0
# 8                                  0                      0
# ...                              ...                    ...
# 50222                              1                      0
# 50223                              1                      0
# 50224                              0                      0
# 50225                              0                      0
# 50226                              1                      0
#
#                CouncilDistrictCode_4  CouncilDistrictCode_5  \
# OSEBuildingID
# 1                                  0                      0
# 2                                  0                      0
# 3                                  0                      0
# 5                                  0                      0
# 8                                  0                      0
# ...                              ...                    ...
# 50222                              0                      0
# 50223                              0                      0
# 50224                              0                      0
# 50225                              0                      0
# 50226                              0                      0
#
#                CouncilDistrictCode_6  CouncilDistrictCode_7
# OSEBuildingID
# 1                                  0                      1
# 2                                  0                      1
# 3                                  0                      1
# 5                                  0                      1
# 8                                  0                      1
# ...                              ...                    ...
# 50222                              0                      0
# 50223                              0                      0
# 50224                              0                      1
# 50225                              0                      0
# 50226                              0                      0
#
# [1648 rows x 41 columns]

# %%
data.loc[data['SourceEUI(kBtu/sf)'].isnull()]
# Out:
#                NumberofBuildings  NumberofFloors  PropertyGFATotal  \
# OSEBuildingID
# 773                          1.0               4             63150
# 26532                        1.0               2             20760
#
#                LargestPropertyUseTypeGFA  ENERGYSTARScore  SiteEUI(kBtu/sf)  \
# OSEBuildingID
# 773                              63150.0              0.0               NaN
# 26532                            20760.0              0.0               NaN
#
#                SiteEUIWN(kBtu/sf)  SourceEUI(kBtu/sf)  SourceEUIWN(kBtu/sf)  \
# OSEBuildingID
# 773                           NaN                 NaN                   NaN
# 26532                         NaN                 NaN                   NaN
#
#                EnergyStarNaN  SiteEnergyUse(kBtu)  SiteEnergyUseWN(kBtu)  \
# OSEBuildingID
# 773                        1                  NaN                    NaN
# 26532                      1                  NaN                    NaN
#
#                TotalGHGEmissions  GHGEmissionsIntensity  Age  \
# OSEBuildingID
# 773                          NaN                    NaN   92
# 26532                        NaN                    NaN   88
#
#                PropertyGFAParking(%)  PropertyGFABuilding(s)(%)  SteamUse(%)  \
# OSEBuildingID
# 773                              0.0                      100.0          NaN
# 26532                            0.0                      100.0          NaN
#
#                Electricity(%)  NaturalGas(%)  \
# OSEBuildingID
# 773                       NaN            NaN
# 26532                     NaN            NaN
#
#                PrimaryPropertyType_Distribution Center  \
# OSEBuildingID
# 773                                                  0
# 26532                                                0
#
#                PrimaryPropertyType_Hotel  PrimaryPropertyType_K-12 School  \
# OSEBuildingID
# 773                                    0                                0
# 26532                                  0                                0
#
#                PrimaryPropertyType_Large Office  \
# OSEBuildingID
# 773                                           0
# 26532                                         0
#
#                PrimaryPropertyType_Medical Office  \
# OSEBuildingID
# 773                                             0
# 26532                                           0
#
#                PrimaryPropertyType_Mixed Use Property  \
# OSEBuildingID
# 773                                                 0
# 26532                                               1
#
#                PrimaryPropertyType_Other  PrimaryPropertyType_Retail Store  \
# OSEBuildingID
# 773                                    0                                 0
# 26532                                  0                                 0
#
#                PrimaryPropertyType_Self-Storage Facility  \
# OSEBuildingID
# 773                                                    0
# 26532                                                  0
#
#                PrimaryPropertyType_Small- and Mid-Sized Office  \
# OSEBuildingID
# 773                                                          1
# 26532                                                        0
#
#                PrimaryPropertyType_Supermarket / Grocery Store  \
# OSEBuildingID
# 773                                                          0
# 26532                                                        0
#
#                PrimaryPropertyType_University  PrimaryPropertyType_Warehouse  \
# OSEBuildingID
# 773                                         0                              0
# 26532                                       0                              0
#
#                PrimaryPropertyType_Worship Facility  CouncilDistrictCode_1  \
# OSEBuildingID
# 773                                               0                      0
# 26532                                             0                      0
#
#                CouncilDistrictCode_2  CouncilDistrictCode_3  \
# OSEBuildingID
# 773                                0                      0
# 26532                              0                      0
#
#                CouncilDistrictCode_4  CouncilDistrictCode_5  \
# OSEBuildingID
# 773                                0                      0
# 26532                              1                      0
#
#                CouncilDistrictCode_6  CouncilDistrictCode_7
# OSEBuildingID
# 773                                0                      1
# 26532                              0                      0

# %%
data.loc[data['TotalGHGEmissions'].isnull(), 'TotalGHGEmissions'] = np.mean(data['TotalGHGEmissions'])

# %%
data.loc[data['GHGEmissionsIntensity'].isnull(), 'GHGEmissionsIntensity'] = np.mean(data['GHGEmissionsIntensity'])

# %%
data =data[~data.isin([np.nan, np.inf, -np.inf]).any(1)]

# %%
X = data[['Age','NumberofBuildings','NumberofFloors','PropertyGFATotal','PropertyGFAParking(%)',
        'PropertyGFABuilding(s)(%)','LargestPropertyUseTypeGFA','ENERGYSTARScore','EnergyStarNaN',
        'PrimaryPropertyType_Distribution Center', 'PrimaryPropertyType_Hotel',
       'PrimaryPropertyType_K-12 School', 
       'PrimaryPropertyType_Large Office',
       'PrimaryPropertyType_Medical Office',
       'PrimaryPropertyType_Mixed Use Property',
       'PrimaryPropertyType_Other',
       'PrimaryPropertyType_Retail Store',
       'PrimaryPropertyType_Self-Storage Facility',
       'PrimaryPropertyType_Small- and Mid-Sized Office',
       'PrimaryPropertyType_Supermarket / Grocery Store',
       'PrimaryPropertyType_University', 'PrimaryPropertyType_Warehouse',
       'PrimaryPropertyType_Worship Facility','CouncilDistrictCode_1',
       'CouncilDistrictCode_2', 'CouncilDistrictCode_3',
       'CouncilDistrictCode_4', 'CouncilDistrictCode_5',
       'CouncilDistrictCode_6', 'CouncilDistrictCode_7']]


y = data['TotalGHGEmissions']

# %%
X.head()
# Out:
#                Age  NumberofBuildings  NumberofFloors  PropertyGFATotal  \
# OSEBuildingID
# 1               89                1.0              12             88434
# 2               20                1.0              11            103566
# 3               47                1.0              41            956110
# 5               90                1.0              10             61320
# 8               36                1.0              18            175580
#
#                PropertyGFAParking(%)  PropertyGFABuilding(s)(%)  \
# OSEBuildingID
# 1                           0.000000                 100.000000
# 2                          14.545314                  85.454686
# 3                          20.574829                  79.425171
# 5                           0.000000                 100.000000
# 8                          35.311539                  64.688461
#
#                LargestPropertyUseTypeGFA  ENERGYSTARScore  EnergyStarNaN  \
# OSEBuildingID
# 1                                88434.0             60.0              0
# 2                                83880.0             61.0              0
# 3                               756493.0             43.0              0
# 5                                61320.0             56.0              0
# 8                               123445.0             75.0              0
#
#                PrimaryPropertyType_Distribution Center  \
# OSEBuildingID
# 1                                                    0
# 2                                                    0
# 3                                                    0
# 5                                                    0
# 8                                                    0
#
#                PrimaryPropertyType_Hotel  PrimaryPropertyType_K-12 School  \
# OSEBuildingID
# 1                                      1                                0
# 2                                      1                                0
# 3                                      1                                0
# 5                                      1                                0
# 8                                      1                                0
#
#                PrimaryPropertyType_Large Office  \
# OSEBuildingID
# 1                                             0
# 2                                             0
# 3                                             0
# 5                                             0
# 8                                             0
#
#                PrimaryPropertyType_Medical Office  \
# OSEBuildingID
# 1                                               0
# 2                                               0
# 3                                               0
# 5                                               0
# 8                                               0
#
#                PrimaryPropertyType_Mixed Use Property  \
# OSEBuildingID
# 1                                                   0
# 2                                                   0
# 3                                                   0
# 5                                                   0
# 8                                                   0
#
#                PrimaryPropertyType_Other  PrimaryPropertyType_Retail Store  \
# OSEBuildingID
# 1                                      0                                 0
# 2                                      0                                 0
# 3                                      0                                 0
# 5                                      0                                 0
# 8                                      0                                 0
#
#                PrimaryPropertyType_Self-Storage Facility  \
# OSEBuildingID
# 1                                                      0
# 2                                                      0
# 3                                                      0
# 5                                                      0
# 8                                                      0
#
#                PrimaryPropertyType_Small- and Mid-Sized Office  \
# OSEBuildingID
# 1                                                            0
# 2                                                            0
# 3                                                            0
# 5                                                            0
# 8                                                            0
#
#                PrimaryPropertyType_Supermarket / Grocery Store  \
# OSEBuildingID
# 1                                                            0
# 2                                                            0
# 3                                                            0
# 5                                                            0
# 8                                                            0
#
#                PrimaryPropertyType_University  PrimaryPropertyType_Warehouse  \
# OSEBuildingID
# 1                                           0                              0
# 2                                           0                              0
# 3                                           0                              0
# 5                                           0                              0
# 8                                           0                              0
#
#                PrimaryPropertyType_Worship Facility  CouncilDistrictCode_1  \
# OSEBuildingID
# 1                                                 0                      0
# 2                                                 0                      0
# 3                                                 0                      0
# 5                                                 0                      0
# 8                                                 0                      0
#
#                CouncilDistrictCode_2  CouncilDistrictCode_3  \
# OSEBuildingID
# 1                                  0                      0
# 2                                  0                      0
# 3                                  0                      0
# 5                                  0                      0
# 8                                  0                      0
#
#                CouncilDistrictCode_4  CouncilDistrictCode_5  \
# OSEBuildingID
# 1                                  0                      0
# 2                                  0                      0
# 3                                  0                      0
# 5                                  0                      0
# 8                                  0                      0
#
#                CouncilDistrictCode_6  CouncilDistrictCode_7
# OSEBuildingID
# 1                                  0                      1
# 2                                  0                      1
# 3                                  0                      1
# 5                                  0                      1
# 8                                  0                      1

# %%
y.head()
# Out:
# OSEBuildingID
# 1     249.98
# 2     295.86
# 3    2089.28
# 5     286.43
# 8     505.01
# Name: TotalGHGEmissions, dtype: float64

# %%
std_scale = StandardScaler().fit(X)
X_scale = std_scale.transform(X)
X_train, X_test, y_train, y_test = train_test_split(X_scale, y, test_size=0.2, random_state=7)

# %%
X_test.shape
# Out:
# (326, 30)

# %%
dr = DummyRegressor(strategy="mean")

# %%
dr.fit(X_train, y_train)
# Out:
# DummyRegressor()

# %%
dr.score(X_test, y_test)
# Out:
# -0.0032552824409906034

# %%
baseline_error = mean_squared_error(y_test, dr.predict(y_test), squared=False)

# %%
baseline_error
# Out:
# 511.7310722960844

# %%
lr = LinearRegression()

# %%
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
mean_squared_error(y_test, lr.predict(X_test), squared=False)
# Out:
# 434.3348145422259

# %%
n_alphas = 100
alphas = np.logspace(-1, 6, n_alphas)

ridge = Ridge()

coefs = []
errors = []
for a in alphas:
    ridge.set_params(alpha=a)
    ridge.fit(X_train, y_train)
    coefs.append(ridge.coef_)
    errors.append([baseline_error, mean_squared_error(y_test, ridge.predict(X_test), squared=False)])

# %%
ax = plt.gca()

ax.plot(alphas, coefs)
ax.set_xscale('log')
plt.xlabel('alpha')
plt.ylabel('weights')
plt.title('Ridge coefficients as a function of the regularization')
plt.axis('tight')
plt.show()

# %%
ax = plt.gca()

ax.plot(alphas, errors)
ax.set_xscale('log')
plt.xlabel('alpha')
plt.ylabel('error')
plt.axis('tight')
plt.show()

# %%
np.min(errors)
# Out:
# 417.2151649902057

# %%
errors.index(min(errors))
# Out:
# 41

# %%
errors[errors.index(min(errors))]
# Out:
# [511.7310722960844, 417.2151649902057]

# %%
alphas[errors.index(min(errors))]
# Out:
# 79.24828983539169

# %%
ridge.set_params(alpha = alphas[errors.index(min(errors))])
ridge.fit(X_train, y_train)
# Out:
# Ridge(alpha=79.24828983539169)

# %%
mean_squared_error(y_test, ridge.predict(X_test), squared=False)
# Out:
# 417.2151649902057

# %%
n_alphas = 100
alphas = np.logspace(-1, 4, n_alphas)
lasso = Lasso(fit_intercept=False)

coefs = []
errors = []
for a in alphas:
    lasso.set_params(alpha=a)
    lasso.fit(X_train, y_train)
    coefs.append(lasso.coef_)
    errors.append([baseline_error, np.mean((lasso.predict(X_test) - y_test) ** 2)])

# %%
ax = plt.gca()

ax.plot(alphas, coefs)
ax.set_xscale('log')
plt.xlabel('alpha')
plt.ylabel('weights')
plt.axis('tight')
plt.show()

# %%
ax = plt.gca()

ax.plot(alphas, errors)
ax.set_xscale('log')
plt.xlabel('alpha')
plt.ylabel('error')
plt.axis('tight')
plt.show()

# %%
np.min(errors)
# Out:
# 511.7310722960844

# %%
errors.index(min(errors))
# Out:
# 40

# %%
alphas[errors.index(min(errors))]
# Out:
# 10.476157527896651

# %%
lasso.set_params(alpha = alphas[errors.index(min(errors))])
lasso.fit(X_train, y_train)
# Out:
# Lasso(alpha=10.476157527896651, fit_intercept=False)

# %%
mean_squared_error(y_test, lasso.predict(X_test), squared=False)
# Out:
# 458.0814361983909

# %%
params = {'alpha': np.logspace(0, 7, 150)}

# %%
grid = GridSearchCV(Ridge(), params, cv = 10)

# %%
grid.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=10, estimator=Ridge(),
#              param_grid={'alpha': array([1.00000000e+00, 1.11424288e+00, 1.24153719e+00, 1.38337396e+00,
#        1.54141458e+00, 1.71751022e+00, 1.91372352e+00, 2.13235280e+00,
#        2.37595891e+00, 2.64739529e+00, 2.94984134e+00, 3.28683970e+00,
#        3.66233771e+00, 4.08073370e+00, 4.54692846e+00, 5.06638264e+00,
#        5.64518076e+00, 6.29010244e+00, 7.00870182e+00, 7...
#        6.69118990e+05, 7.45561067e+05, 8.30736107e+05, 9.25641789e+05,
#        1.03138977e+06, 1.14921870e+06, 1.28050875e+06, 1.42679775e+06,
#        1.58979923e+06, 1.77142246e+06, 1.97379486e+06, 2.19928686e+06,
#        2.45053971e+06, 2.73049642e+06, 3.04243618e+06, 3.39001283e+06,
#        3.77729765e+06, 4.20882699e+06, 4.68965549e+06, 5.22541521e+06,
#        5.82238167e+06, 6.48754729e+06, 7.22870335e+06, 8.05453121e+06,
#        8.97470401e+06, 1.00000000e+07])})

# %%
best_params = grid.best_params_
best_params
# Out:
# {'alpha': 911.4472598521194}

# %%
res = pd.DataFrame(grid.cv_results_)
res.head()
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time param_alpha  \
# 0       0.000766      0.000263         0.000223        0.000019         1.0
# 1       0.000675      0.000041         0.000211        0.000005    1.114243
# 2       0.000687      0.000084         0.000210        0.000005    1.241537
# 3       0.000673      0.000061         0.000208        0.000005    1.383374
# 4       0.000681      0.000079         0.000210        0.000008    1.541415
#
#                           params  split0_test_score  split1_test_score  \
# 0                 {'alpha': 1.0}          -0.613075          -5.732162
# 1  {'alpha': 1.1142428752325104}          -0.609073          -5.720192
# 2  {'alpha': 1.2415371850064116}          -0.604677          -5.706950
# 3  {'alpha': 1.3833739627296213}          -0.599858          -5.692310
# 4  {'alpha': 1.5414145817536447}          -0.594583          -5.676138
#
#    split2_test_score  split3_test_score  split4_test_score  split5_test_score  \
# 0          -0.350393           0.364381           0.478081           0.398374
# 1          -0.348059           0.365792           0.477900           0.398717
# 2          -0.345496           0.367342           0.477693           0.399088
# 3          -0.342684           0.369042           0.477456           0.399488
# 4          -0.339604           0.370904           0.477185           0.399917
#
#    split6_test_score  split7_test_score  split8_test_score  split9_test_score  \
# 0           0.242524          -0.052061           0.343105          -0.142171
# 1           0.241899          -0.049320           0.343208          -0.140947
# 2           0.241211          -0.046313           0.343317          -0.139610
# 3           0.240455          -0.043020           0.343430          -0.138152
# 4           0.239625          -0.039420           0.343546          -0.136567
#
#    mean_test_score  std_test_score  rank_test_score
# 0        -0.506340        1.775162              150
# 1        -0.504007        1.771786              149
# 2        -0.501439        1.768048              148
# 3        -0.498615        1.763914              147
# 4        -0.495514        1.759344              146

# %%
cols = [i for i in res.columns if "split" not in i]
res = res[cols].sort_values('rank_test_score')
res.head()
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  param_alpha  \
# 63       0.000625      0.000010         0.000202        0.000007    911.44726
# 62       0.000631      0.000012         0.000202        0.000004   817.996938
# 64       0.000631      0.000010         0.000202        0.000004  1015.573615
# 61       0.000629      0.000010         0.000202        0.000005    734.12804
# 65       0.000629      0.000014         0.000202        0.000006  1131.595665
#
#                            params  mean_test_score  std_test_score  \
# 63   {'alpha': 911.4472598521194}         0.337483        0.229469
# 62   {'alpha': 817.9969377519476}         0.337094        0.225572
# 64   {'alpha': 1015.573615440418}         0.336449        0.231015
# 61   {'alpha': 734.1280397070122}         0.335194        0.219190
# 65  {'alpha': 1131.5956652786067}         0.334087        0.230403
#
#     rank_test_score
# 63                1
# 62                2
# 64                3
# 61                4
# 65                5

# %%
def resultize(grid):
    """Faire un dataframe lisible pour grid"""
    
    res = pd.DataFrame(grid.cv_results_)
    cols = [i for i in res.columns if "split" not in i]
    res = res[cols].sort_values('rank_test_score')

    return res

# %%
resultize(grid).head()
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  param_alpha  \
# 63       0.000625      0.000010         0.000202        0.000007    911.44726
# 62       0.000631      0.000012         0.000202        0.000004   817.996938
# 64       0.000631      0.000010         0.000202        0.000004  1015.573615
# 61       0.000629      0.000010         0.000202        0.000005    734.12804
# 65       0.000629      0.000014         0.000202        0.000006  1131.595665
#
#                            params  mean_test_score  std_test_score  \
# 63   {'alpha': 911.4472598521194}         0.337483        0.229469
# 62   {'alpha': 817.9969377519476}         0.337094        0.225572
# 64   {'alpha': 1015.573615440418}         0.336449        0.231015
# 61   {'alpha': 734.1280397070122}         0.335194        0.219190
# 65  {'alpha': 1131.5956652786067}         0.334087        0.230403
#
#     rank_test_score
# 63                1
# 62                2
# 64                3
# 61                4
# 65                5

# %%
ridge = Ridge(**grid.best_params_)
ridge.fit(X_train, y_train)
y_pred = ridge.predict(X_test)

# %%
def score(estimator):
    """Calcule et affiche le train et test score"""
    
    tr_score = estimator.score(X_train, y_train).round(4)
    te_score = estimator.score(X_test, y_test).round(4)
    
    print(f"score train : {tr_score}, score test {te_score} ")

# %%
score(ridge)
# Out:
# score train : 0.3374, score test 0.2791

# %%
mean_squared_error(y_test, ridge.predict(X_test), squared=False)
# Out:
# 417.6107984566835

# %%
params = {"alpha": np.logspace(-1, 3, 100)}
grid = GridSearchCV(Lasso(), params, cv=10)
grid.fit(X_train, y_train)
resultize(grid).head()
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_alpha  \
# 76       0.000685      0.000028         0.000242    1.709480e-06  117.681195
# 75       0.000685      0.000027         0.000242    1.602201e-06  107.226722
# 77       0.000682      0.000029         0.000242    1.266988e-06  129.154967
# 74       0.000689      0.000029         0.000243    1.831949e-06   97.700996
# 78       0.000680      0.000023         0.000242    8.327603e-07  141.747416
#
#                            params  mean_test_score  std_test_score  \
# 76  {'alpha': 117.68119524349991}         0.302161        0.241540
# 75  {'alpha': 107.22672220103243}         0.301759        0.238017
# 77   {'alpha': 129.1549665014884}         0.300899        0.241819
# 74   {'alpha': 97.70099572992257}         0.300103        0.232221
# 78   {'alpha': 141.7474162926806}         0.297461        0.237681
#
#     rank_test_score
# 76                1
# 75                2
# 77                3
# 74                4
# 78                5

# %%
lasso = Lasso(**grid.best_params_)
lasso.fit(X_train, y_train)
y_pred = lasso.predict(X_test)
mean_squared_error(y_test, y_pred, squared=False)
# Out:
# 445.69094577804555

# %%
tt = TransformedTargetRegressor(regressor = Ridge(),
                               func = np.log1p,
                               inverse_func = np.expm1)
tt.fit(X_train, y_train)
# Out:
# TransformedTargetRegressor(func=<ufunc 'log1p'>, inverse_func=<ufunc 'expm1'>,
#                            regressor=Ridge())

# %%
y_pred = tt.predict(X_test)
mean_squared_error(y_test, y_pred, squared=False)
# Out:
# 469.8639424900487

# %%
params = {'regressor__alpha': np.logspace(0, 7, 100)}
grid = GridSearchCV(tt, params, cv = 10)

# %%
grid.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=10,
#              estimator=TransformedTargetRegressor(func=<ufunc 'log1p'>,
#                                                   inverse_func=<ufunc 'expm1'>,
#                                                   regressor=Ridge()),
#              param_grid={'regressor__alpha': array([1.00000000e+00, 1.17681195e+00, 1.38488637e+00, 1.62975083e+00,
#        1.91791026e+00, 2.25701972e+00, 2.65608778e+00, 3.12571585e+00,
#        3.67837977e+00, 4.32876128e+00, 5.09413801e+00, 5.99484250e+00,
#        7.0548023...
#        2.36448941e+05, 2.78255940e+05, 3.27454916e+05, 3.85352859e+05,
#        4.53487851e+05, 5.33669923e+05, 6.28029144e+05, 7.39072203e+05,
#        8.69749003e+05, 1.02353102e+06, 1.20450354e+06, 1.41747416e+06,
#        1.66810054e+06, 1.96304065e+06, 2.31012970e+06, 2.71858824e+06,
#        3.19926714e+06, 3.76493581e+06, 4.43062146e+06, 5.21400829e+06,
#        6.13590727e+06, 7.22080902e+06, 8.49753436e+06, 1.00000000e+07])})

# %%
resultize(grid)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 53       0.001125      0.000003         0.000277    2.127677e-06
# 54       0.001126      0.000004         0.000276    1.485292e-06
# 55       0.001140      0.000027         0.000276    7.215856e-07
# 56       0.001131      0.000003         0.000278    1.815898e-06
# 57       0.001129      0.000004         0.000277    1.454939e-06
# ..            ...           ...              ...             ...
# 4        0.001134      0.000004         0.000278    7.707229e-07
# 3        0.001140      0.000005         0.000279    1.541630e-06
# 2        0.001144      0.000004         0.000281    2.312046e-06
# 1        0.001405      0.000498         0.000284    4.541796e-06
# 0        0.001232      0.000160         0.000292    1.435779e-05
#
#    param_regressor__alpha                                    params  \
# 53            5590.810183   {'regressor__alpha': 5590.810182512223}
# 54            6579.332247  {'regressor__alpha': 6579.3322465756755}
# 55            7742.636827    {'regressor__alpha': 7742.63682681127}
# 56            9111.627561   {'regressor__alpha': 9111.627561154886}
# 57            10722.67222  {'regressor__alpha': 10722.672220103232}
# ..                    ...                                       ...
# 4                 1.91791  {'regressor__alpha': 1.9179102616724886}
# 3                1.629751  {'regressor__alpha': 1.6297508346206442}
# 2                1.384886   {'regressor__alpha': 1.384886371393873}
# 1                1.176812  {'regressor__alpha': 1.1768119524349985}
# 0                     1.0                 {'regressor__alpha': 1.0}
#
#     mean_test_score  std_test_score  rank_test_score
# 53     5.913413e-02    2.766760e-01                1
# 54     3.709985e-02    2.227728e-01                2
# 55     8.265632e-03    1.476738e-01                3
# 56    -1.211650e-02    9.723825e-02                4
# 57    -2.543519e-02    6.743251e-02                5
# ..              ...             ...              ...
# 4     -3.781667e+33    1.134500e+34               96
# 3     -4.102045e+33    1.230613e+34               97
# 2     -4.397322e+33    1.319197e+34               98
# 1     -4.666291e+33    1.399887e+34               99
# 0     -4.908833e+33    1.472650e+34              100
#
# [100 rows x 9 columns]

# %%
svr = SVR()

# %%
svr.fit(X_train, y_train)
# Out:
# SVR()

# %%
y_pred = svr.predict(X_test)
mean_squared_error(y_test, y_pred, squared=False)
# Out:
# 518.9267938229668

# %%
params = {'kernel': ['sigmoid','rbf','poly','sigmoid'],
         'C': [0.1,1,100,1000],
         'degree': [1,2,3,4,5,6]}
grid = GridSearchCV(SVR(), params, cv=10)
grid.fit(X_train, y_train)
resultize(grid).head()
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 93       0.049842      0.005784         0.003379        0.000053    1000
# 89       0.051018      0.006080         0.003526        0.000075    1000
# 85       0.049918      0.005824         0.003411        0.000066    1000
# 81       0.049796      0.005810         0.003349        0.000027    1000
# 77       0.049860      0.005890         0.003389        0.000073    1000
#
#    param_degree param_kernel                                     params  \
# 93            6          rbf  {'C': 1000, 'degree': 6, 'kernel': 'rbf'}
# 89            5          rbf  {'C': 1000, 'degree': 5, 'kernel': 'rbf'}
# 85            4          rbf  {'C': 1000, 'degree': 4, 'kernel': 'rbf'}
# 81            3          rbf  {'C': 1000, 'degree': 3, 'kernel': 'rbf'}
# 77            2          rbf  {'C': 1000, 'degree': 2, 'kernel': 'rbf'}
#
#     mean_test_score  std_test_score  rank_test_score
# 93         0.310998        0.146318                1
# 89         0.310998        0.146318                1
# 85         0.310998        0.146318                1
# 81         0.310998        0.146318                1
# 77         0.310998        0.146318                1

# %%
svr = SVR(**grid.best_params_)
svr.fit(X_train, y_train)
y_pred = svr.predict(X_test)
mean_squared_error(y_test, y_pred, squared=False)
# Out:
# 449.53153131615863
