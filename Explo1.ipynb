# %%
import pandas as pd
pd.options.display.max_columns=200
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats as st
import seaborn as sns
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
import plotly.express as px
import researchpy as rp
import warnings 
warnings.filterwarnings('ignore')
from sklearn.dummy import DummyRegressor

# %%
data = pd.read_csv('2016_Building_Energy_Benchmarking.csv')

# %%
data
# Out:
#       OSEBuildingID  DataYear        BuildingType PrimaryPropertyType  \
# 0                 1      2016      NonResidential               Hotel
# 1                 2      2016      NonResidential               Hotel
# 2                 3      2016      NonResidential               Hotel
# 3                 5      2016      NonResidential               Hotel
# 4                 8      2016      NonResidential               Hotel
# ...             ...       ...                 ...                 ...
# 3371          50222      2016  Nonresidential COS              Office
# 3372          50223      2016  Nonresidential COS               Other
# 3373          50224      2016  Nonresidential COS               Other
# 3374          50225      2016  Nonresidential COS  Mixed Use Property
# 3375          50226      2016  Nonresidential COS  Mixed Use Property
#
#                              PropertyName           Address     City State  \
# ...

# %%
data.set_index('OSEBuildingID', inplace = True)

# %%
data['Neighborhood'].value_counts(dropna=False)
# Out:
# DOWNTOWN                  573
# EAST                      453
# MAGNOLIA / QUEEN ANNE     423
# GREATER DUWAMISH          375
# NORTHEAST                 280
# LAKE UNION                251
# NORTHWEST                 210
# SOUTHWEST                 166
# NORTH                     145
# BALLARD                   126
# CENTRAL                   107
# SOUTHEAST                  95
# DELRIDGE                   80
# North                      42
# Central                    27
# Northwest                  11
# Ballard                     7
# Delridge                    4
# DELRIDGE NEIGHBORHOODS      1
# Name: Neighborhood, dtype: int64

# %%
data['CouncilDistrictCode'].value_counts(dropna=False)
# Out:
# 7    1037
# 3     596
# 2     509
# 4     367
# 5     338
# 1     282
# 6     247
# Name: CouncilDistrictCode, dtype: int64

# %%
data['BuildingType'].value_counts(dropna=False)
# Out:
# NonResidential          1460
# Multifamily LR (1-4)    1018
# Multifamily MR (5-9)     580
# Multifamily HR (10+)     110
# SPS-District K-12         98
# Nonresidential COS        85
# Campus                    24
# Nonresidential WA          1
# Name: BuildingType, dtype: int64

# %%
df=data.copy()

# %%
df.drop(labels=df.loc[df['BuildingType'].str.startswith("Multifamily")].index, axis = 0, inplace = True)

# %%
df
# Out:
#                DataYear        BuildingType PrimaryPropertyType  \
# OSEBuildingID
# 1                  2016      NonResidential               Hotel
# 2                  2016      NonResidential               Hotel
# 3                  2016      NonResidential               Hotel
# 5                  2016      NonResidential               Hotel
# 8                  2016      NonResidential               Hotel
# ...                 ...                 ...                 ...
# 50222              2016  Nonresidential COS              Office
# 50223              2016  Nonresidential COS               Other
# 50224              2016  Nonresidential COS               Other
# 50225              2016  Nonresidential COS  Mixed Use Property
# 50226              2016  Nonresidential COS  Mixed Use Property
#
#                                       PropertyName           Address     City  \
# OSEBuildingID
# 1                             Mayflower park hotel     405 Olive way  Seattle
# ...

# %%
df['PrimaryPropertyType'].value_counts(dropna=False)
# Out:
# Small- and Mid-Sized Office    292
# Other                          250
# Warehouse                      187
# Large Office                   173
# K-12 School                    139
# Mixed Use Property             114
# Retail Store                    91
# Hotel                           76
# Worship Facility                71
# Distribution Center             53
# Supermarket / Grocery Store     40
# Medical Office                  39
# Self-Storage Facility           28
# University                      24
# Residence Hall                  21
# Senior Care Community           20
# Refrigerated Warehouse          12
# Restaurant                      12
# Hospital                        10
# Laboratory                      10
# Low-Rise Multifamily             3
# Office                           3
# Name: PrimaryPropertyType, dtype: int64

# %%
# Out:
# Empty DataFrame
# Columns: [DataYear, BuildingType, PrimaryPropertyType, PropertyName, Address, City, State, ZipCode, TaxParcelIdentificationNumber, CouncilDistrictCode, Neighborhood, Latitude, Longitude, Age, NumberofBuildings, NumberofFloors, PropertyGFATotal, PropertyGFAParking, PropertyGFABuilding(s), ListOfAllPropertyUseTypes, LargestPropertyUseType, LargestPropertyUseTypeGFA, SecondLargestPropertyUseType, SecondLargestPropertyUseTypeGFA, ThirdLargestPropertyUseType, ThirdLargestPropertyUseTypeGFA, YearsENERGYSTARCertified, ENERGYSTARScore, SiteEUI(kBtu/sf), SiteEUIWN(kBtu/sf), SourceEUI(kBtu/sf), SourceEUIWN(kBtu/sf), SiteEnergyUse(kBtu), SiteEnergyUseWN(kBtu), SteamUse(kBtu), Electricity(kWh), Electricity(kBtu), NaturalGas(therms), NaturalGas(kBtu), DefaultData, Comments, ComplianceStatus, Outlier, TotalGHGEmissions, GHGEmissionsIntensity]
# Index: []

# %%
df['YearBuilt']=2016-df['YearBuilt']
df.rename(columns={'YearBuilt' : 'Age'},inplace = True)

# %%
df
# Out:
#                DataYear        BuildingType PrimaryPropertyType  \
# OSEBuildingID
# 1                  2016      NonResidential               Hotel
# 2                  2016      NonResidential               Hotel
# 3                  2016      NonResidential               Hotel
# 5                  2016      NonResidential               Hotel
# 8                  2016      NonResidential               Hotel
# ...                 ...                 ...                 ...
# 50222              2016  Nonresidential COS              Office
# 50223              2016  Nonresidential COS               Other
# 50224              2016  Nonresidential COS               Other
# 50225              2016  Nonresidential COS  Mixed Use Property
# 50226              2016  Nonresidential COS  Mixed Use Property
#
#                                       PropertyName           Address     City  \
# OSEBuildingID
# 1                             Mayflower park hotel     405 Olive way  Seattle
# ...

# %%
df.loc[df['Electricity(kBtu)'].isnull()]
# Out:
#                DataYear    BuildingType          PrimaryPropertyType  \
# OSEBuildingID
# 773                2016  NonResidential  Small- and Mid-Sized Office
# 26532              2016  NonResidential           Mixed Use Property
#
#                    PropertyName                 Address     City State  \
# OSEBuildingID
# 773            SEATTLE BUILDING         215 COLUMBIA ST  Seattle    WA
# 26532          KALBERG BUILDING  4515 UNIVERSITY WAY NE  Seattle    WA
#
#                ZipCode TaxParcelIdentificationNumber  CouncilDistrictCode  \
# OSEBuildingID
# 773            98104.0                    0939000245                    7
# 26532          98105.0                    8816401120                    4
#
#               Neighborhood  Latitude  Longitude  Age  NumberofBuildings  \
# OSEBuildingID
# 773               DOWNTOWN  47.60380 -122.33293   92                NaN
# 26532            NORTHEAST  47.66182 -122.31345   88                NaN
#
# ...

# %%
df.loc[df['NaturalGas(kBtu)'].isnull()]
# Out:
#                DataYear    BuildingType          PrimaryPropertyType  \
# OSEBuildingID
# 773                2016  NonResidential  Small- and Mid-Sized Office
# 26532              2016  NonResidential           Mixed Use Property
#
#                    PropertyName                 Address     City State  \
# OSEBuildingID
# 773            SEATTLE BUILDING         215 COLUMBIA ST  Seattle    WA
# 26532          KALBERG BUILDING  4515 UNIVERSITY WAY NE  Seattle    WA
#
#                ZipCode TaxParcelIdentificationNumber  CouncilDistrictCode  \
# OSEBuildingID
# 773            98104.0                    0939000245                    7
# 26532          98105.0                    8816401120                    4
#
#               Neighborhood  Latitude  Longitude  Age  NumberofBuildings  \
# OSEBuildingID
# 773               DOWNTOWN  47.60380 -122.33293   92                NaN
# 26532            NORTHEAST  47.66182 -122.31345   88                NaN
#
# ...

# %%
df.loc[df['SteamUse(kBtu)'].isnull()]
# Out:
#                DataYear    BuildingType          PrimaryPropertyType  \
# OSEBuildingID
# 773                2016  NonResidential  Small- and Mid-Sized Office
# 26532              2016  NonResidential           Mixed Use Property
#
#                    PropertyName                 Address     City State  \
# OSEBuildingID
# 773            SEATTLE BUILDING         215 COLUMBIA ST  Seattle    WA
# 26532          KALBERG BUILDING  4515 UNIVERSITY WAY NE  Seattle    WA
#
#                ZipCode TaxParcelIdentificationNumber  CouncilDistrictCode  \
# OSEBuildingID
# 773            98104.0                    0939000245                    7
# 26532          98105.0                    8816401120                    4
#
#               Neighborhood  Latitude  Longitude  Age  NumberofBuildings  \
# OSEBuildingID
# 773               DOWNTOWN  47.60380 -122.33293   92                NaN
# 26532            NORTHEAST  47.66182 -122.31345   88                NaN
#
# ...

# %%
df.loc[df['NumberofBuildings'].isnull()]
# Out:
#                DataYear    BuildingType          PrimaryPropertyType  \
# OSEBuildingID
# 773                2016  NonResidential  Small- and Mid-Sized Office
# 26532              2016  NonResidential           Mixed Use Property
#
#                    PropertyName                 Address     City State  \
# OSEBuildingID
# 773            SEATTLE BUILDING         215 COLUMBIA ST  Seattle    WA
# 26532          KALBERG BUILDING  4515 UNIVERSITY WAY NE  Seattle    WA
#
#                ZipCode TaxParcelIdentificationNumber  CouncilDistrictCode  \
# OSEBuildingID
# 773            98104.0                    0939000245                    7
# 26532          98105.0                    8816401120                    4
#
#               Neighborhood  Latitude  Longitude  Age  NumberofBuildings  \
# OSEBuildingID
# 773               DOWNTOWN  47.60380 -122.33293   92                NaN
# 26532            NORTHEAST  47.66182 -122.31345   88                NaN
#
# ...

# %%
df.drop(labels = df.loc[df['NumberofBuildings'].isnull()].index, axis = 0, inplace = True)

# %%
df.loc[df['SiteEUI(kBtu/sf)'].isnull()]
# Out:
#                DataYear    BuildingType PrimaryPropertyType  \
# OSEBuildingID
# 435                2016  NonResidential               Other
#
#                                      PropertyName      Address     City State  \
# OSEBuildingID
# 435            Washington State Convention Center  705 Pike St  Seattle    WA
#
#                ZipCode TaxParcelIdentificationNumber  CouncilDistrictCode  \
# OSEBuildingID
# 435            98101.0                    1978200105                    7
#
#               Neighborhood  Latitude  Longitude  Age  NumberofBuildings  \
# OSEBuildingID
# 435               DOWNTOWN  47.61195 -122.33167   26                1.0
#
#                NumberofFloors  PropertyGFATotal  PropertyGFAParking  \
# OSEBuildingID
# 435                         6           1400000                   0
#
#                PropertyGFABuilding(s)   ListOfAllPropertyUseTypes  \
# OSEBuildingID
# 435                           1400000  Convention Center, Parking
#
# ...

# %%
df['PropertyGFAParking']=df['PropertyGFAParking']/df['PropertyGFATotal']*100
df['PropertyGFABuilding(s)']=df['PropertyGFABuilding(s)']/df['PropertyGFATotal']*100

# %%
df.rename(columns={'PropertyGFAParking' : 'PropertyGFAParking (%)' , 'PropertyGFABuilding(s)' : 'PropertyGFABuilding(s) (%)'},inplace = True)

# %%
df
# Out:
#                DataYear        BuildingType PrimaryPropertyType  \
# OSEBuildingID
# 1                  2016      NonResidential               Hotel
# 2                  2016      NonResidential               Hotel
# 3                  2016      NonResidential               Hotel
# 5                  2016      NonResidential               Hotel
# 8                  2016      NonResidential               Hotel
# ...                 ...                 ...                 ...
# 50222              2016  Nonresidential COS              Office
# 50223              2016  Nonresidential COS               Other
# 50224              2016  Nonresidential COS               Other
# 50225              2016  Nonresidential COS  Mixed Use Property
# 50226              2016  Nonresidential COS  Mixed Use Property
#
#                                       PropertyName           Address     City  \
# OSEBuildingID
# 1                             Mayflower park hotel     405 Olive way  Seattle
# ...

# %%
df['Outlier'].value_counts(dropna=False)
# Out:
# NaN             1651
# Low outlier       15
# High outlier       2
# Name: Outlier, dtype: int64

# %%
df.drop(labels=df.loc[~df['Outlier'].isnull()].index, axis = 0, inplace = True)

# %%
df
# Out:
#                DataYear        BuildingType PrimaryPropertyType  \
# OSEBuildingID
# 1                  2016      NonResidential               Hotel
# 2                  2016      NonResidential               Hotel
# 3                  2016      NonResidential               Hotel
# 5                  2016      NonResidential               Hotel
# 8                  2016      NonResidential               Hotel
# ...                 ...                 ...                 ...
# 50222              2016  Nonresidential COS              Office
# 50223              2016  Nonresidential COS               Other
# 50224              2016  Nonresidential COS               Other
# 50225              2016  Nonresidential COS  Mixed Use Property
# 50226              2016  Nonresidential COS  Mixed Use Property
#
#                                       PropertyName           Address     City  \
# OSEBuildingID
# 1                             Mayflower park hotel     405 Olive way  Seattle
# ...

# %%
df['Electricity(kBtu)']+df['SteamUse(kBtu)']+df['NaturalGas(kBtu)']
# Out:
# OSEBuildingID
# 1        7.226362e+06
# 2        8.387933e+06
# 3        7.258702e+07
# 5        6.794583e+06
# 8        1.417260e+07
#              ...
# 50222    8.497459e+05
# 50223    9.502760e+05
# 50224    5.765898e+06
# 50225    7.194712e+05
# 50226    1.152896e+06
# Length: 1651, dtype: float64

# %%
df['SteamUse(kBtu)']=df['SteamUse(kBtu)']/df['SiteEnergyUse(kBtu)']*100
df['Electricity(kBtu)']=df['Electricity(kBtu)']/df['SiteEnergyUse(kBtu)']*100
df['NaturalGas(kBtu)']=df['NaturalGas(kBtu)']/df['SiteEnergyUse(kBtu)']*100

# %%
df.rename(columns={'SteamUse(kBtu)' : 'SteamUse (%)' , 'Electricity(kBtu)' : 'Electricity (%)' , 'NaturalGas(kBtu)' : 'NaturalGas(%)'},inplace = True)

# %%
basket = ['DataYear','BuildingType','PropertyName','Address','City','State','ZipCode','TaxParcelIdentificationNumber',
         'Neighborhood','Latitude','Longitude','ListOfAllPropertyUseTypes','LargestPropertyUseType','SecondLargestPropertyUseType','SecondLargestPropertyUseTypeGFA',
         'ThirdLargestPropertyUseType','ThirdLargestPropertyUseTypeGFA','YearsENERGYSTARCertified','Electricity(kWh)',
         'NaturalGas(therms)','Comments','DefaultData','ComplianceStatus','Outlier']

# %%
df.drop(labels=basket , axis = 1, inplace = True)

# %%
df
# Out:
#               PrimaryPropertyType  CouncilDistrictCode  Age  \
# OSEBuildingID
# 1                           Hotel                    7   89
# 2                           Hotel                    7   20
# 3                           Hotel                    7   47
# 5                           Hotel                    7   90
# 8                           Hotel                    7   36
# ...                           ...                  ...  ...
# 50222                      Office                    2   26
# 50223                       Other                    2   12
# 50224                       Other                    7   42
# 50225          Mixed Use Property                    1   27
# 50226          Mixed Use Property                    2   78
#
#                NumberofBuildings  NumberofFloors  PropertyGFATotal  \
# OSEBuildingID
# 1                            1.0              12             88434
# 2                            1.0              11            103566
# ...

# %%
df['PrimaryPropertyType'].value_counts()
# Out:
# Small- and Mid-Sized Office    289
# Other                          247
# Warehouse                      187
# Large Office                   170
# K-12 School                    137
# Mixed Use Property             114
# Retail Store                    89
# Hotel                           75
# Worship Facility                69
# Distribution Center             53
# Supermarket / Grocery Store     40
# Medical Office                  39
# Self-Storage Facility           28
# University                      24
# Residence Hall                  21
# Senior Care Community           20
# Refrigerated Warehouse          12
# Restaurant                      12
# Hospital                        10
# Laboratory                      10
# Office                           3
# Low-Rise Multifamily             2
# Name: PrimaryPropertyType, dtype: int64

# %%
pd.get_dummies(df, columns = ['PrimaryPropertyType'])
# Out:
#                CouncilDistrictCode  Age  NumberofBuildings  NumberofFloors  \
# OSEBuildingID
# 1                                7   89                1.0              12
# 2                                7   20                1.0              11
# 3                                7   47                1.0              41
# 5                                7   90                1.0              10
# 8                                7   36                1.0              18
# ...                            ...  ...                ...             ...
# 50222                            2   26                1.0               1
# 50223                            2   12                1.0               1
# 50224                            7   42                1.0               1
# 50225                            1   27                1.0               1
# 50226                            2   78                1.0               1
#
# ...

# %%
df.loc[df['TotalGHGEmissions'].isnull()]
# Out:
#                        PrimaryPropertyType  CouncilDistrictCode  Age  \
# OSEBuildingID
# 773            Small- and Mid-Sized Office                    7   92
# 26532                   Mixed Use Property                    4   88
#
#                NumberofBuildings  NumberofFloors  PropertyGFATotal  \
# OSEBuildingID
# 773                          NaN               4             63150
# 26532                        NaN               2             20760
#
#                PropertyGFAParking (%)  PropertyGFABuilding(s) (%)  \
# OSEBuildingID
# 773                               0.0                       100.0
# 26532                             0.0                       100.0
#
#                LargestPropertyUseTypeGFA  ENERGYSTARScore  SiteEUI(kBtu/sf)  \
# OSEBuildingID
# 773                                  NaN              NaN               NaN
# 26532                                NaN              NaN               NaN
#
# ...

# %%
cols = ['NumberofBuildings','NumberofFloors','PropertyGFATotal','PropertyGFAParking (%)','PropertyGFABuilding(s) (%)','LargestPropertyUseTypeGFA','ENERGYSTARScore','SiteEUI(kBtu/sf)','SiteEUIWN(kBtu/sf)','SourceEUI(kBtu/sf)','SourceEUIWN(kBtu/sf)','SiteEnergyUse(kBtu)','SiteEnergyUseWN(kBtu)','SteamUse (%)','Electricity (%)','NaturalGas(%)','TotalGHGEmissions','GHGEmissionsIntensity']

for col in cols:
   df[col].replace([np.inf, -np.inf], np.nan).dropna().plot.hist(bins=50, logx=False)
   plt.title(col)
   plt.show()

# %%
df
# Out:
#               PrimaryPropertyType  CouncilDistrictCode  Age  \
# OSEBuildingID
# 1                           Hotel                    7   89
# 2                           Hotel                    7   20
# 3                           Hotel                    7   47
# 5                           Hotel                    7   90
# 8                           Hotel                    7   36
# ...                           ...                  ...  ...
# 50222                      Office                    2   26
# 50223                       Other                    2   12
# 50224                       Other                    7   42
# 50225          Mixed Use Property                    1   27
# 50226          Mixed Use Property                    2   78
#
#                NumberofBuildings  NumberofFloors  PropertyGFATotal  \
# OSEBuildingID
# 1                            1.0              12             88434
# 2                            1.0              11            103566
# ...

# %%
d = df[['SteamUse (%)', 'Electricity (%)','NaturalGas(%)']]

# Tracer un pairplot des colonnes sélectionnées
sns.pairplot(d)
plt.show()

# %%
 df.loc[df['Electricity (%)']+df['SteamUse (%)']+df['NaturalGas(%)']>105]
# Out:
#                        PrimaryPropertyType  CouncilDistrictCode  Age  \
# OSEBuildingID
# 757                           Large Office                    7   37
# 25661          Small- and Mid-Sized Office                    7  107
#
#                NumberofBuildings  NumberofFloors  PropertyGFATotal  \
# OSEBuildingID
# 757                          1.0               7            131143
# 25661                        0.0               3             47215
#
#                PropertyGFAParking (%)  PropertyGFABuilding(s) (%)  \
# OSEBuildingID
# 757                         66.461801                   33.538199
# 25661                        0.000000                  100.000000
#
#                LargestPropertyUseTypeGFA  ENERGYSTARScore  SiteEUI(kBtu/sf)  \
# OSEBuildingID
# 757                             120248.0             93.0              39.5
# 25661                            23659.0             58.0              45.5
#
# ...

# %%
pd.get_dummies(df, columns = ['PrimaryPropertyType']).to_csv("data.csv", index=False)

# %%
df.isnull().sum()
# Out:
# PrimaryPropertyType             0
# CouncilDistrictCode             0
# Age                             0
# NumberofBuildings               2
# NumberofFloors                  0
# PropertyGFATotal                0
# PropertyGFAParking (%)          0
# PropertyGFABuilding(s) (%)      0
# LargestPropertyUseTypeGFA       6
# ENERGYSTARScore               568
# SiteEUI(kBtu/sf)                3
# SiteEUIWN(kBtu/sf)              3
# SourceEUI(kBtu/sf)              2
# SourceEUIWN(kBtu/sf)            2
# SiteEnergyUse(kBtu)             2
# SiteEnergyUseWN(kBtu)           3
# SteamUse (%)                   18
# Electricity (%)                11
# NaturalGas(%)                  14
# TotalGHGEmissions               2
# GHGEmissionsIntensity           2
# dtype: int64
